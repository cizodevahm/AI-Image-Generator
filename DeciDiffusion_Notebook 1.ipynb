# %%
# %%capture
# !pip install diffusers --upgrade
# !pip install invisible_watermark transformers accelerate safetensors
# !pip install matplotlib
# Out:
# Collecting diffusers
#   Downloading diffusers-0.23.1-py3-none-any.whl (1.7 MB)
#      ---------------------------------------- 1.7/1.7 MB 4.1 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.4.0-cp310-none-win_amd64.whl (277 kB)
#      -------------------------------------- 277.4/277.4 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\lenovo\anaconda3\lib\site-packages (from diffusers) (1.23.5)
# Collecting huggingface-hub>=0.13.2
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      -------------------------------------- 311.7/311.7 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from diffusers) (2.28.1)
# Requirement already satisfied: importlib-metadata in c:\users\lenovo\anaconda3\lib\site-packages (from diffusers) (4.11.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from diffusers) (2022.7.9)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from diffusers) (3.9.0)
# Requirement already satisfied: Pillow in c:\users\lenovo\anaconda3\lib\site-packages (from diffusers) (9.4.0)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (4.64.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (4.4.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (6.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub>=0.13.2->diffusers) (22.0)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2023.10.0-py3-none-any.whl (166 kB)
#      ------------------------------------- 166.4/166.4 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=0.5 in c:\users\lenovo\anaconda3\lib\site-packages (from importlib-metadata->diffusers) (3.11.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->diffusers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->diffusers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->diffusers) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->diffusers) (1.26.14)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub>=0.13.2->diffusers) (0.4.6)
# Installing collected packages: safetensors, fsspec, huggingface-hub, diffusers
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.11.0
#     Uninstalling fsspec-2022.11.0:
#       Successfully uninstalled fsspec-2022.11.0
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.10.1
#     Uninstalling huggingface-hub-0.10.1:
#       Successfully uninstalled huggingface-hub-0.10.1
# Successfully installed diffusers-0.23.1 fsspec-2023.10.0 huggingface-hub-0.19.4 safetensors-0.4.0
# Collecting invisible_watermark
#   Downloading invisible_watermark-0.2.0-py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: transformers in c:\users\lenovo\anaconda3\lib\site-packages (4.24.0)
# Collecting accelerate
#   Downloading accelerate-0.24.1-py3-none-any.whl (261 kB)
#      -------------------------------------- 261.4/261.4 kB 8.1 MB/s eta 0:00:00
# Requirement already satisfied: safetensors in c:\users\lenovo\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: opencv-python>=4.1.0.25 in c:\users\lenovo\anaconda3\lib\site-packages (from invisible_watermark) (4.7.0.72)
# Requirement already satisfied: torch in c:\users\lenovo\anaconda3\lib\site-packages (from invisible_watermark) (2.0.1)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\lenovo\anaconda3\lib\site-packages (from invisible_watermark) (1.23.5)
# Requirement already satisfied: Pillow>=6.0.0 in c:\users\lenovo\anaconda3\lib\site-packages (from invisible_watermark) (9.4.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\lenovo\anaconda3\lib\site-packages (from invisible_watermark) (1.4.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.11.4)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: psutil in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (2023.10.0)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from torch->invisible_watermark) (1.11.1)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch->invisible_watermark) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch->invisible_watermark) (3.1.2)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (2023.5.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch->invisible_watermark) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->torch->invisible_watermark) (1.2.1)
# Installing collected packages: invisible_watermark, accelerate
# Successfully installed accelerate-0.24.1 invisible_watermark-0.2.0

# %%
# !python --version
# Out:
# Python 3.10.9

# %%
# !pip install git+https://github.com/huggingface/transformers
# Out:
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to c:\users\lenovo\appdata\local\temp\pip-req-build-vbdzqxge
#   Resolved https://github.com/huggingface/transformers to commit 35551f9a0f66a22de4971b4a51b3c172d3b87f95
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (4.64.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (22.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (2022.7.9)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (2.28.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (1.23.5)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.19.3 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (0.19.4)
# Collecting tokenizers<0.19,>=0.14
#   Downloading tokenizers-0.15.0-cp310-none-win_amd64.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (6.0)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers==4.36.0.dev0) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0.dev0) (4.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.19.3->transformers==4.36.0.dev0) (2023.10.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.27->transformers==4.36.0.dev0) (0.4.6)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers==4.36.0.dev0) (2023.5.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers==4.36.0.dev0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers==4.36.0.dev0) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers==4.36.0.dev0) (1.26.14)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml): started
#   Building wheel for transformers (pyproject.toml): finished with status 'done'
#   Created wheel for transformers: filename=transformers-4.36.0.dev0-py3-none-any.whl size=8049451 sha256=6b3429459d22ddbc2e8af585a8ab1ba63e344308b0007d609066042cdea10ad0
#   Stored in directory: C:\Users\LENOVO\AppData\Local\Temp\pip-ephem-wheel-cache-4az4_9f7\wheels\c0\14\d6\6c9a5582d2ac191ec0a483be151a4495fe1eb2a6706ca49f1b
# Successfully built transformers
# Installing collected packages: tokenizers, transformers
#   Attempting uninstall: tokenizers
#     Found existing installation: tokenizers 0.11.4
#     Uninstalling tokenizers-0.11.4:
#       Successfully uninstalled tokenizers-0.11.4
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers 'C:\Users\LENOVO\AppData\Local\Temp\pip-req-build-vbdzqxge'
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\LENOVO\\anaconda3\\Lib\\site-packages\\~okenizers\\tokenizers.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.

# %% [markdown]
# In my case I have to install lower version transformers.

# %%
# !pip install transformers -U
# Out:
# Requirement already satisfied: transformers in c:\users\lenovo\anaconda3\lib\site-packages (4.24.0)
# Collecting transformers
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ---------------------------------------- 7.9/7.9 MB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (1.23.5)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.19.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (22.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2.28.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.15.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (2022.7.9)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (3.9.0)
# Requirement already satisfied: tqdm>=4.27 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (4.64.1)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\lenovo\anaconda3\lib\site-packages (from transformers) (0.4.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.10.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.4.0)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->transformers) (2023.5.7)
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.24.0
#     Uninstalling transformers-4.24.0:
#       Successfully uninstalled transformers-4.24.0
# Successfully installed transformers-4.35.2

# %%
# !pip install -U accelerate
# Out:
# Requirement already satisfied: accelerate in c:\users\lenovo\anaconda3\lib\site-packages (0.24.1)
# Requirement already satisfied: pyyaml in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (6.0)
# Requirement already satisfied: numpy>=1.17 in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (1.23.5)
# Requirement already satisfied: huggingface-hub in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (0.19.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (22.0)
# Requirement already satisfied: psutil in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: torch>=1.10.0 in c:\users\lenovo\anaconda3\lib\site-packages (from accelerate) (2.0.1)
# Requirement already satisfied: filelock in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.9.0)
# Requirement already satisfied: typing-extensions in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (4.4.0)
# Requirement already satisfied: sympy in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (2.8.4)
# Requirement already satisfied: jinja2 in c:\users\lenovo\anaconda3\lib\site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2023.10.0)
# Requirement already satisfied: requests in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (2.28.1)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\lenovo\anaconda3\lib\site-packages (from huggingface-hub->accelerate) (4.64.1)
# Requirement already satisfied: colorama in c:\users\lenovo\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub->accelerate) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lenovo\anaconda3\lib\site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\lenovo\anaconda3\lib\site-packages (from requests->huggingface-hub->accelerate) (1.26.14)
# Requirement already satisfied: mpmath>=0.19 in c:\users\lenovo\anaconda3\lib\site-packages (from sympy->torch>=1.10.0->accelerate) (1.2.1)

# %% [markdown]
# # Text-to-image generation with DeciDiffusion and HuggingFace 🧨diffusers
#
#
# **Note:** All generation times shown below are from a single high-RAM, RTX 3050 GPU 4GB

# %%
import torch
import os
import time
from IPython.core.display import display, HTML

from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
from diffusers import StableDiffusionPipeline
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_3872\4013913749.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML

# %% [markdown]
# # 1️⃣ Step 1: Load custom pipeline from DeciDiffusion repo

# %%
# It took plenty of time to load everything in my case
deci_diffusion_pipeline = StableDiffusionPipeline.from_pretrained('Deci/DeciDiffusion-v1-0',
                                                   custom_pipeline='Deci/DeciDiffusion-v1-0',
                                                   torch_dtype=torch.float16
                                                   )
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]

# %% [markdown]
# # 2️⃣ Step 2:  Load custom unet from DeciDiffusion repo, set it to `pipeline` object's UNet

# %%
deci_diffusion_pipeline.unet = deci_diffusion_pipeline.unet.from_pretrained('Deci/DeciDiffusion-v1-0',
                                              subfolder='flexible_unet',
                                              torch_dtype=torch.float16)

# Move pipeline to device
deci_diffusion_pipeline = deci_diffusion_pipeline.to('cuda')
# Out:
# The config attributes {'act_fn': 'silu', 'addition_embed_type': None, 'addition_embed_type_num_heads': 64, 'addition_time_embed_dim': None, 'attention_head_dim': 8, 'attention_type': 'default', 'block_out_channels': [320, 640, 1280, 1280], 'center_input_sample': False, 'class_embed_type': None, 'class_embeddings_concat': False, 'configurations': {'add_downsample': [True, True, True], 'add_upsample': [True, True, False], 'add_upsample_mid_block': True, 'cross_attention_dim': 768, 'down_blocks_in_channels': [320, 320, 640], 'down_blocks_num_attentions': [0, 1, 3], 'down_blocks_num_resnets': [2, 2, 1], 'down_blocks_out_channels': [320, 640, 1280], 'mid_num_attentions': 2, 'mid_num_resnets': 4, 'mix_block_in_forward': True, 'num_attention_heads': 8, 'prev_output_channels': [1280, 1280, 640], 'resnet_act_fn': 'silu', 'resnet_eps': 1e-05, 'sample_size': 64, 'temb_dim': 1280, 'up_blocks_num_attentions': [6, 3, 0], 'up_blocks_num_resnets': [2, 3, 3]}, 'conv_in_kernel': 3, 'conv_out_kernel': 3, 'cross_attention_dim': 768, 'cross_attention_norm': None, 'down_block_types': ['CrossAttnDownBlock2D', 'CrossAttnDownBlock2D', 'CrossAttnDownBlock2D', 'DownBlock2D'], 'downsample_padding': 1, 'dual_cross_attention': False, 'encoder_hid_dim': None, 'encoder_hid_dim_type': None, 'flip_sin_to_cos': True, 'freq_shift': 0, 'in_channels': 4, 'layers_per_block': 2, 'mid_block_only_cross_attention': None, 'mid_block_scale_factor': 1, 'mid_block_type': 'UNetMidBlock2DCrossAttn', 'norm_eps': 1e-05, 'norm_num_groups': 32, 'num_attention_heads': None, 'num_class_embeds': None, 'only_cross_attention': False, 'out_channels': 4, 'projection_class_embeddings_input_dim': None, 'resnet_out_scale_factor': 1.0, 'resnet_skip_time_act': False, 'resnet_time_scale_shift': 'default', 'sample_size': 64, 'time_cond_proj_dim': None, 'time_embedding_act_fn': None, 'time_embedding_dim': None, 'time_embedding_type': 'positional', 'timestep_post_act': None, 'transformer_layers_per_block': 1, 'up_block_types': ['UpBlock2D', 'CrossAttnUpBlock2D', 'CrossAttnUpBlock2D', 'CrossAttnUpBlock2D'], 'upcast_attention': False, 'use_linear_projection': False} were passed to FlexibleUNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.

# %% [markdown]
# # 3️⃣ Step 3: Generate Image

# %%
def text_to_image(pipeline, prompt):

    # Start the timer
    start_time = time.time()

    # Call the pipeline function directly
    result = pipeline([prompt], generator=torch.Generator("cuda").manual_seed(42))

    # Calculate and print the elapsed time
    elapsed_time = time.time() - start_time
    display(HTML(f'<span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: {elapsed_time:.2f} seconds</span>'))

    img = result.images[0]

    filename = prompt.replace(' ', '_')
    if len(filename) > 100:  # Limit filename to 100 characters
        filename = filename[:100]

    # Incorporate the pipeline's class name into the filename
    pipeline_name = pipeline.__class__.__name__
    #save_path = os.path.join("/content", f"{pipeline_name}_{filename}.png")
    save_path = os.path.join("D:/deciDiffusion", f"{pipeline_name}_{filename}.png")
#     img.save(save_path)

    # Display the saved image
    plt.imshow(img)
    plt.axis('off')
    plt.show()
    return save_path

# %%
text_to_image(deci_diffusion_pipeline, "Creat realistic view of New tech city with indian design, very detailed real photo.")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.31 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Creat_realistic_view_of_New_tech_city_with_indian_design,_very_detailed_real_photo..png'

# %%
text_to_image(deci_diffusion_pipeline, "Illustrate a serene view of the Ganges River at Himaliya mountains flowing bitween the snow in evening Ganga Aarti.")

# Cat and Lion sitting together and enjoying ice cream
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 12.82 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Illustrate_a_serene_view_of_the_Ganges_River_at_Himaliya_mountains_flowing_bitween_the_snow_in_eveni.png'

# %%
text_to_image(deci_diffusion_pipeline, "Create a colorful image capturing the spirit of the Holi festival, with people throwing vibrant powdered colors.")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 2.21 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Create_a_colorful_image_capturing_the_spirit_of_the_Holi_festival,_with_people_throwing_vibrant_powd.png'

# %%
text_to_image(deci_diffusion_pipeline, "Illustrate a meditative scene of a yogi practicing yoga amidst the serene beauty of the Himalayan mountains with floating river and deers drinking water from it in background.")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.29 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Illustrate_a_meditative_scene_of_a_yogi_practicing_yoga_amidst_the_serene_beauty_of_the_Himalayan_mo.png'

# %%
text_to_image(deci_diffusion_pipeline, "a water color painting of the Golden Temple awash in the glow of morning light with a vanilla sky")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 2.90 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_a_water_color_painting_of_the_Golden_Temple_awash_in_the_glow_of_morning_light_with_a_vanilla_sky.png'

# %%
text_to_image(deci_diffusion_pipeline, "a realistic portrait of albert einstein with a bewildered expression")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 1.28 seconds</span>
# '/content/DeciDiffusionPipeline_a_realistic_portrait_of_albert_einstein_with_a_bewildered_expression.png'

# %%
text_to_image(deci_diffusion_pipeline, "Emma Watson as a powerful mysterious sorceress, casting lightning magic, detailed clothing")
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 1.31 seconds</span>
# '/content/DeciDiffusionPipeline_Emma_Watson_as_a_powerful_mysterious_sorceress,_casting_lightning_magic,_detailed_clothing.png'

# %%
prompt = "Emma Watson portrait photo of a asia old warrior chief, tribal panther make up, blue on red, side profile, looking away, serious eyes, 50mm portrait photography, hard rim lighting photography–beta –ar 2:3 –beta –upbeta –beta –upbeta –beta –upbeta"

text_to_image(deci_diffusion_pipeline, prompt)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.39 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Emma_Watson_portrait_photo_of_a_asia_old_warrior_chief,_tribal_panther_make_up,_blue_on_red,_side_pr.png'

# %%
prompt = "Real photo of a superhero concept of Spiderman having Captain America's sheild and cottagecore of Super Man!!, background hyper detailed, character concept,"
text_to_image(deci_diffusion_pipeline, prompt)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.27 seconds</span>
# "D:/deciDiffusion\\DeciDiffusionPipeline_Real_photo_of_a_superhero_concept_of_Spiderman_having_Captain_America's_sheild_and_cottagecore_of_Su.png"

# %%
prompt = "Generate an image of a serene Japanese garden with a koi pond and cherry blossoms."
text_to_image(deci_diffusion_pipeline, prompt)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 3.31 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Generate_an_image_of_a_serene_Japanese_garden_with_a_koi_pond_and_cherry_blossoms..png'

# %%
prompt = "Visualize a peaceful beach at sunset with gentle waves and a colorful sky between mountains."
text_to_image(deci_diffusion_pipeline, prompt)
# Out:
#   0%|          | 0/30 [00:00<?, ?it/s]
# <span style="color: #3264ff; font-weight:bold;font-size: 20px;">Time taken to generate: 5.25 seconds</span>
# 'D:/deciDiffusion\\DeciDiffusionPipeline_Visualize_a_peaceful_beach_at_sunset_with_gentle_waves_and_a_colorful_sky_between_mountains..png'
